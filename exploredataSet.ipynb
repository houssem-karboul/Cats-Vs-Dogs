# %%
from utilities import * #import load_data()

# %%
x_train,y_train,x_test,y_test=load_data(); #load DataSet

# %%
print(x_train.shape) #1000 picture 64*64
print(y_train.shape)
print(np.unique(y_train,return_counts=True)) #display trainSet info : 50%cat /50%Dogs
# Out:
# (1000, 64, 64)
# (1000, 1)
# (array([0., 1.]), array([500, 500]))

# %%
print(x_test.shape) #200 picture 64*64
print(y_test.shape)
print(np.unique(y_train,return_counts=True))#display testSet info : 50%cat /50%Dogs
# Out:
# (200, 64, 64)
# (200, 1)
# (array([0., 1.]), array([500, 500]))
